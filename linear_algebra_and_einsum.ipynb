# %% [markdown]
# <a href="https://colab.research.google.com/github/sanaullah-developer/tensorflow_practice/blob/main/linear_algebra_and_einsum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
t1=tf.constant([
    [1,2],
    [3,4]
])
t2=tf.constant([
    [5,6],
    [7,8]
])

# %%
# linalg is a module in tensorflow mainly related to linear algebra
print(tf.linalg.matmul(t1,t2)) # matmul is used for matrix multiplication
print(t1@t2)# we can also use the "@" between matrix for matrix multiplication
# Out:
# tf.Tensor(
# [[19 22]
#  [43 50]], shape=(2, 2), dtype=int32)
# tf.Tensor(
# [[19 22]
#  [43 50]], shape=(2, 2), dtype=int32)

# %%
print("matrix before transpose", t1)
print(" matrix after transpose", tf.transpose(t1))
# Out:
# matrix before transpose tf.Tensor(
# [[1 2]
#  [3 4]], shape=(2, 2), dtype=int32)
#  matrix after transpose tf.Tensor(
# [[1 3]
#  [2 4]], shape=(2, 2), dtype=int32)

# %%
print(tf.linalg.adjoint(t1))
# Out:
# tf.Tensor(
# [[1 3]
#  [2 4]], shape=(2, 2), dtype=int32)

# %%
print("dot product in normal way",t1*t2)
print("dot product in einsum way",tf.einsum("ij,ij-> ij",t1,t2)) #dot product
# Out:
# dot product in normal way tf.Tensor(
# [[ 5 12]
#  [21 32]], shape=(2, 2), dtype=int32)
# dot product in einsum way tf.Tensor(
# [[ 5 12]
#  [21 32]], shape=(2, 2), dtype=int32)

# %%
print("cross product in normal way",t1@t2)
print("cross product in einsum way",tf.einsum("ij,jk->ik",t1,t2))
# Out:
# cross product in normal way tf.Tensor(
# [[19 22]
#  [43 50]], shape=(2, 2), dtype=int32)
# cross product in einsum way tf.Tensor(
# [[19 22]
#  [43 50]], shape=(2, 2), dtype=int32)

# %%
print("transpose in normal way",tf.transpose(t1))
print("transpose in einsum way",tf.einsum("ij->ji",t1))
# Out:
# transpose in normal way tf.Tensor(
# [[1 3]
#  [2 4]], shape=(2, 2), dtype=int32)
# transpose in einsum way tf.Tensor(
# [[1 3]
#  [2 4]], shape=(2, 2), dtype=int32)

# %%
A=tf.constant([
    [1,2,3,4],
    [5,6,7,8],
    [2,5,1,9]
])

# %%
#axis 0 sum
#print(np.sum(A, axis=0))
print("einsum A : ")
print(np.einsum("ij->i",A))

#axis 1 sum
#print(np.sum(A, axis=1))
print("einsum A : ")
print(np.einsum("ij->j",A))
# Out:
# einsum A :
# [10 26 17]
# einsum A :
# [ 8 13 11 21]

# %%
#example from "attention is all you need" paper
Q=np.random.randn(32,64,512)
K=np.random.randn(32,128,512)

# %%
np.einsum("bqm,bkm->bqk",Q,K)
# Out:
# array([[[-10.01327456,   4.2205692 ,  13.19380914, ..., -13.66139689,
#            0.99947614,   4.86814498],
#         [  9.77456219,   9.6899635 , -11.63495044, ...,   4.63534019,
#          -38.12642467, -14.35085831],
#         [ 34.16877037, -11.55724307, -17.06586768, ...,  12.1181691 ,
#          -56.19505172,  23.25955224],
#         ...,
#         [ -8.61991065,  -2.31953221, -10.41688824, ...,  21.99485915,
#          -19.69765755,  41.93355398],
#         [ 15.86582606, -45.40020928,  -6.43653823, ..., -27.2145958 ,
#            0.8758741 , -21.70853557],
#         [ 16.13477619,  12.8452395 , -14.0359137 , ...,  17.05536348,
#           45.1986153 ,  25.81955894]],
#
#        [[ 30.42331019,  18.91733933,   6.86288034, ...,   9.62821553,
#           23.69253334,   9.01294388],
#         [ 23.05615207,  -0.95334251,   6.00015043, ...,  -8.44080686,
#           19.07920601,   6.07684395],
#         [ -9.27536677,  22.69860099,  -4.13502096, ..., -26.06884179,
#           -3.4774514 ,  22.34974282],
#         ...,
#         [  6.34360479,  -3.93564273,   8.56458876, ..., -13.61628665,
#          -49.68281575,  10.07988017],
#         [ -2.68883465,   4.39315252,  20.20376118, ...,   4.34309355,
#          -20.46139716,  -9.95820782],
#         [-15.94070715, -18.26807989, -13.39113549, ..., -28.03628994,
#            6.55514204,   8.14356778]],
#
#        [[-13.08032042,   9.26094568,  16.02472763, ...,  -8.96697177,
#          -19.31965564,  -8.57940276],
#         [  3.15046101,  10.52724781,  -3.21105743, ...,  10.12709899,
#           13.56835065,  17.10546881],
#         [ -1.15556485,  18.48213273,  -7.43476875, ..., -11.7375085 ,
#            3.79393648,  15.78962277],
#         ...,
#         [ -0.51546195,   8.62245307, -26.84413727, ..., -24.56035703,
#           22.87434432,  19.10368541],
#         [ -9.25570693,  -9.62323555,  -2.22748128, ..., -38.06545191,
#            4.45995853,  -9.82360651],
#         [ 24.02826898,  25.96403882, -47.32175392, ...,   7.04798533,
#           19.8255846 ,   2.25512318]],
#
#        ...,
#
#        [[-20.18399264,  17.81029463,   8.90817137, ...,  19.02681265,
#           -6.2582637 ,   1.28984522],
#         [  0.30238771,  29.99713683,   7.71632138, ...,  25.67330695,
#           11.61706522,   0.8343335 ],
#         [  6.82661489,  -5.83210166, -14.33606124, ...,   2.76126492,
#           -4.41180006, -21.40582931],
#         ...,
#         [-13.6629405 ,  17.35628319,  11.67091879, ...,   7.35144718,
#          -50.64043003, -25.56322219],
#         [ 33.53652302,   4.96501759, -12.35445404, ...,  -0.37899878,
#          -13.82348039, -15.52461047],
#         [  0.13710217,  15.21472551,  27.84498744, ...,  28.86448217,
#          -23.78861905, -11.17052661]],
#
#        [[ 14.02655616,   9.44879322, -13.99404385, ..., -19.11740601,
#           -2.54635692,  35.13796741],
#         [ -3.6732797 , -12.50480499,  -9.68569276, ..., -32.53101076,
#            6.16110186, -56.9545997 ],
#         [ 33.49543647,  22.06017069,  19.02586172, ...,  15.61791631,
#          -27.59480906,  30.75330962],
#         ...,
#         [ -4.14552493, -31.31425075,  22.16028991, ...,   8.90018897,
#           14.67013992, -34.64151013],
#         [ 27.77630665,  10.85475025, -27.79864729, ..., -27.89228167,
#           40.76098279, -82.55920096],
#         [ 63.37998586,   6.32080736,  14.3758929 , ...,  36.70163123,
#          -21.09790561,  22.46039876]],
#
#        [[-16.08826603, -21.18402235,   1.15857168, ..., -10.01093946,
#          -14.57552167,  24.0347483 ],
#         [-36.48903851,   3.39403537,   2.95324223, ..., -25.47938835,
#          -20.34212133, -24.19132778],
#         [ 16.62567307,  -9.32864084,   8.25443201, ..., -35.82820898,
#            6.76911709,  18.55680325],
#         ...,
#         [ 23.03002869, -12.10945283, -20.81700751, ...,  27.91604005,
#           45.73970799,  -3.4747286 ],
#         [ -3.8823306 , -21.33182146, -25.98002501, ..., -15.28207628,
#            9.94678554,   9.45993946],
#         [ -5.59493719,   7.50234918,   8.41142927, ..., -20.66226625,
#           63.93446908,   7.62028312]]])
